# %%
pip install altair vega_datasets
# Out:
# Collecting altair
#   Downloading altair-4.2.2-py3-none-any.whl (813 kB)
#      |████████████████████████████████| 813 kB 4.7 MB/s eta 0:00:01
# Collecting vega_datasets
#   Downloading vega_datasets-0.9.0-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 11.1 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /Users/roshanmehta/opt/anaconda3/lib/python3.9/site-packages (from altair) (1.21.5)
# Requirement already satisfied: pandas>=0.18 in /Users/roshanmehta/opt/anaconda3/lib/python3.9/site-packages (from altair) (1.4.2)
# Requirement already satisfied: toolz in /Users/roshanmehta/opt/anaconda3/lib/python3.9/site-packages (from altair) (0.11.2)
# Requirement already satisfied: jinja2 in /Users/roshanmehta/opt/anaconda3/lib/python3.9/site-packages (from altair) (2.11.3)
# Requirement already satisfied: entrypoints in /Users/roshanmehta/opt/anaconda3/lib/python3.9/site-packages (from altair) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /Users/roshanmehta/opt/anaconda3/lib/python3.9/site-packages (from altair) (4.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/roshanmehta/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/roshanmehta/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair) (21.4.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/roshanmehta/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.18->altair) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/roshanmehta/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.18->altair) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/roshanmehta/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.18->altair) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/roshanmehta/opt/anaconda3/lib/python3.9/site-packages (from jinja2->altair) (2.0.1)
# Installing collected packages: vega-datasets, altair
# Successfully installed altair-4.2.2 vega-datasets-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# packages
import numpy as np
import pandas as pd
import altair as alt

# raw data
air_raw = pd.read_csv('/Users/roshanmehta/Downloads/PSTAT/PSTAT 100/Projects/MP1/air-quality.csv')
cbsa_info = pd.read_csv('/Users/roshanmehta/Downloads/PSTAT/PSTAT 100/Projects/MP1/cbsa-info.csv')

# merging data
data = pd.merge(air_raw, cbsa_info, how = 'left', on = 'CBSA')

# combining columns
data['Pollutant statistic'] = data[['Pollutant','Trend Statistic']].agg('-'.join, axis=1)

# dropping irrelevant columns
data.drop(columns = ['Pollutant', 'Trend Statistic', 'Number of Trends Sites'])

# reordering columns
data = data.loc[:,['CBSA','Core Based Statistical Area','Pollutant statistic', "2000", "2001", "2002", 
                   "2003", "2004", "2005", '2006', "2007", "2008", "2009", "2010", "2011", "2012", 
                   "2013", "2014", "2015", "2016", "2017", "2018", "2019"]]

data.head(3)
# Out:
#     CBSA Core Based Statistical Area         Pollutant statistic  2000  2001  \
# 0  10100                Aberdeen, SD                PM10-2nd Max  50.0  58.0
# 1  10100                Aberdeen, SD  PM2.5-Weighted Annual Mean   8.6   8.6
# 2  10100                Aberdeen, SD       PM2.5-98th Percentile  23.0  23.0
#
#    2002  2003  2004  2005  2006  ...  2010  2011  2012  2013  2014  2015  \
# 0  59.0  66.0  39.0  48.0  51.0  ...  46.0  29.0  62.0  66.0  36.0  43.0
# 1   7.9   8.4   8.1   9.0   8.2  ...   8.7   7.1   7.5   7.3   6.2   6.2
# 2  20.0  21.0  23.0  23.0  21.0  ...  27.0  18.0  23.0  22.0  17.0  14.0
#
#    2016  2017  2018  2019
# 0  65.0  40.0  49.0  35.0
# 1   5.4   5.8   6.6   5.9
# 2  14.0  13.0  22.0  18.0
#
# [3 rows x 23 columns]

# %%
# tidying the data
# we first need to melt the years into a single 'year' variable and then pivot
tidy_data = data.copy()
tidy_data = tidy_data.drop('Core Based Statistical Area', axis = 1)
tidy_data = tidy_data.melt(
    id_vars =['CBSA', 'Pollutant statistic'],
    value_vars = ["2000", "2001", "2002", "2003", "2004", "2005", '2006', "2007", "2008", "2009", "2010", "2011",
                 "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019"],
    var_name = 'Year',
    value_name = 'Concentration'
).pivot_table(
    index = ['CBSA', 'Year'], 
    columns = ['Pollutant statistic'], 
    values = 'Concentration')

tidy_data.head(21)
# Out:
# Pollutant statistic  CO-2nd Max  NO2-98th Percentile  NO2-Annual Mean  \
# CBSA  Year
# 10100 2000                  NaN                  NaN              NaN
#       2001                  NaN                  NaN              NaN
#       2002                  NaN                  NaN              NaN
#       2003                  NaN                  NaN              NaN
#       2004                  NaN                  NaN              NaN
#       2005                  NaN                  NaN              NaN
#       2006                  NaN                  NaN              NaN
#       2007                  NaN                  NaN              NaN
#       2008                  NaN                  NaN              NaN
#       2009                  NaN                  NaN              NaN
#       2010                  NaN                  NaN              NaN
#       2011                  NaN                  NaN              NaN
#       2012                  NaN                  NaN              NaN
#       2013                  NaN                  NaN              NaN
#       2014                  NaN                  NaN              NaN
#       2015                  NaN                  NaN              NaN
#       2016                  NaN                  NaN              NaN
#       2017                  NaN                  NaN              NaN
#       2018                  NaN                  NaN              NaN
#       2019                  NaN                  NaN              NaN
# 10300 2000                  NaN                  NaN              NaN
#
# Pollutant statistic  O3-4th Max  PM10-2nd Max  PM2.5-98th Percentile  \
# CBSA  Year
# 10100 2000                  NaN          50.0                   23.0
#       2001                  NaN          58.0                   23.0
#       2002                  NaN          59.0                   20.0
#       2003                  NaN          66.0                   21.0
#       2004                  NaN          39.0                   23.0
#       2005                  NaN          48.0                   23.0
#       2006                  NaN          51.0                   21.0
#       2007                  NaN          49.0                   17.0
#       2008                  NaN          69.0                   28.0
#       2009                  NaN          53.0                   23.0
#       2010                  NaN          46.0                   27.0
#       2011                  NaN          29.0                   18.0
#       2012                  NaN          62.0                   23.0
#       2013                  NaN          66.0                   22.0
#       2014                  NaN          36.0                   17.0
#       2015                  NaN          43.0                   14.0
#       2016                  NaN          65.0                   14.0
#       2017                  NaN          40.0                   13.0
#       2018                  NaN          49.0                   22.0
#       2019                  NaN          35.0                   18.0
# 10300 2000                0.082           NaN                    NaN
#
# Pollutant statistic  PM2.5-Weighted Annual Mean  Pb-Max 3-Month Average  \
# CBSA  Year
# 10100 2000                                  8.6                     NaN
#       2001                                  8.6                     NaN
#       2002                                  7.9                     NaN
#       2003                                  8.4                     NaN
#       2004                                  8.1                     NaN
#       2005                                  9.0                     NaN
#       2006                                  8.2                     NaN
#       2007                                  8.0                     NaN
#       2008                                  7.7                     NaN
#       2009                                  8.1                     NaN
#       2010                                  8.7                     NaN
#       2011                                  7.1                     NaN
#       2012                                  7.5                     NaN
#       2013                                  7.3                     NaN
#       2014                                  6.2                     NaN
#       2015                                  6.2                     NaN
#       2016                                  5.4                     NaN
#       2017                                  5.8                     NaN
#       2018                                  6.6                     NaN
#       2019                                  5.9                     NaN
# 10300 2000                                  NaN                     NaN
#
# Pollutant statistic  SO2-99th Percentile
# CBSA  Year
# 10100 2000                           NaN
#       2001                           NaN
#       2002                           NaN
#       2003                           NaN
#       2004                           NaN
#       2005                           NaN
#       2006                           NaN
#       2007                           NaN
#       2008                           NaN
#       2009                           NaN
#       2010                           NaN
#       2011                           NaN
#       2012                           NaN
#       2013                           NaN
#       2014                           NaN
#       2015                           NaN
#       2016                           NaN
#       2017                           NaN
#       2018                           NaN
#       2019                           NaN
# 10300 2000                           NaN

# %%
## PART I - this is merging the data
##########

# number of CBSAs included in the data
data.CBSA.nunique() # there are 351 unique CBSA

# in how many states and territories do the CBSA's reside?
data_mod1 = data.copy()
data_mod1[['City','State/Territory']] = data_mod1['Core Based Statistical Area'].str.split(", ",expand=True)
data_mod1['State/Territory'].str.split('-').explode('State/Territory').unique()
# there are 52 unique territories in the data set - the two territories are PR and DC. 


# In which years were data values recorded?
print(data.columns[3:24]) # we can see that the data was recorded for years 2000-2019.

# How many observations are recorded? / How many variables are measured?
# we will use the tidied data set
tidy_data.shape # 7020 observations were recorded and 9 different variables were measured over a 20 yr. period

# Which variables are non-missing most of the time (i.e., in at least 50% of instances)?
# 7020/2 = 3510
# from this, we can see that the variables 'O3-4th Max', 'PM2.5-98th Percentile', & 'PM2.5-Weighted Annual Mean'
# are non-missing most of the time since they are over 50%.
(7020 - tidy_data.isna().sum()) / int(tidy_data.shape[0]) * 100

# What is PM 2.5 and why is it important?
# PM is particulate matter and 2.5 specifies the size of that particle (2.5 microns or less in diameter). 
# Particulate matter is airborne and not just a single pollutant. It is made up of a mixture of many 
# different chemical substances. For example, the combustion of gasoline, oil, diesel fuel, or wood produce create emmisions, 
# and these make up much of the PM2.5 pollution found the air outdoors. This is important to measure and keep track of 
# because PM2.5 can travel into our respiratory tract, reaching the lungs and even enter the blood stream, posing huge
# health risks. Exposure to increased levels of PM2.5 for extended periods of time is associated with increased chances 
# of early mortality, lung cancer, and heart disease
# Out:
# Index(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019'],
#       dtype='object')
# Pollutant statistic
# CO-2nd Max                    16.809117
# NO2-98th Percentile           19.088319
# NO2-Annual Mean               25.356125
# O3-4th Max                    80.911681
# PM10-2nd Max                  29.344729
# PM2.5-98th Percentile         60.968661
# PM2.5-Weighted Annual Mean    60.968661
# Pb-Max 3-Month Average         4.273504
# SO2-99th Percentile           25.356125
# dtype: float64
